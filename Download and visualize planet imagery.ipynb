# %%
# Pakse, Laos define the coordinates (as obtained using geojson.io)
geojson_geometry = {
  "type": "Polygon",
 "coordinates": [
          [
            [
              105.69929122924805,
              15.17022848289187
            ],
            [
              105.69414138793944,
              15.101128884541032
            ],
            [
              105.79662322998047,
              15.098477132301696
            ],
            [
              105.80572128295898,
              15.169234404007462
            ],
            [
              105.69929122924805,
              15.17022848289187
            ]
          ]
        ]
}

# %%
# geometry filter 
geometry_filter = {
  "type": "GeometryFilter",
  "field_name": "geometry",
  "config": geojson_geometry
}

# specify date range
date_range_filter = {
  "type": "DateRangeFilter",
  "field_name": "acquired",
  "config": {
    "gte": "2018-01-31T00:00:00.000Z", #from
    "lte": "2018-09-01T00:00:00.000Z"  #to
  }
}

#specify the cloud cover as a percentage fraction
cloud_cover_filter = {
  "type": "RangeFilter",
  "field_name": "cloud_cover",
  "config": {
    "lte": 0.2
  }
}

#combined filter = geometry filter, date filter and cloud filter
combined_filter = {
  "type": "AndFilter",
  "config": [geometry_filter, date_range_filter, cloud_cover_filter]
}

# %%
import os
import json
import requests
from requests.auth import HTTPBasicAuth
from planet.api.auth import find_api_key

# API Key stored as an env variable
PLANET_API_KEY = find_api_key()

#specify the item type , list in https://developers.planet.com/docs/api/items-assets/
item_type = "PSScene4Band"

#request object
search_request = {
  "interval": "day",
  "item_types": [item_type],
  "filter": combined_filter
}

# POST request to get the search results
search_result = \
  requests.post(
    'https://api.planet.com/data/v1/quick-search',
    auth=HTTPBasicAuth(PLANET_API_KEY, ''),
    json=search_request)

print(json.dumps(search_result.json(), indent=1))
# Out:
# {
#  "type": "FeatureCollection",
#  "_links": {
#   "_self": "https://api.planet.com/data/v1/searches/0fc0a199a0c74769abfdb07f45ce9e6e/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D",
#   "_first": "https://api.planet.com/data/v1/searches/0fc0a199a0c74769abfdb07f45ce9e6e/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6IG51bGwsICJzb3J0X2xhc3RfaWQiOiBudWxsLCAic29ydF9kZXNjIjogdHJ1ZX0%3D",
#   "_next": "https://api.planet.com/data/v1/searches/0fc0a199a0c74769abfdb07f45ce9e6e/results?_page=eyJxdWVyeV9wYXJhbXMiOiB7fSwgInNvcnRfcHJldiI6IGZhbHNlLCAicGFnZV9zaXplIjogMjUwLCAic29ydF9ieSI6ICJwdWJsaXNoZWQiLCAic29ydF9zdGFydCI6ICIyMDE4LTAyLTExVDE0OjI4OjQ5LjAwMDAwMFoiLCAic29ydF9sYXN0X2lkIjogIjIwMTgwMjExXzAyNTI0NF8xMDE0IiwgInNvcnRfZGVzYyI6IHRydWV9"
#  },
#  "features": [
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.58632277331803,
#        15.083033695165126
#       ],
#       [
#        105.57644778401362,
#        15.134438773774148
#       ],
#       [
#        105.79303208244067,
#        15.17431617405795
#       ],
#       [
#        105.79515867509727,
#        15.163211525483959
#       ],
#       [
#        105.79527751884348,
#        15.163233396289522
#       ],
#       [
#        105.7990145231359,
#        15.144318642099924
#       ],
#       [
#        105.80635046171211,
#        15.106000653033014
#       ],
#       [
#        105.58967487366876,
#        15.066137713790246
#       ],
#       [
#        105.58632277331803,
#        15.083033695165126
#       ]
#      ]
#     ]
#    },
#    "id": "20180629_032536_1053",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180629_032536_1053",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180629_032536_1053/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180629_032536_1053/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-06-29T03:25:36.163315Z",
#     "satellite_id": "1053",
#     "sun_elevation": 66.2,
#     "pixel_resolution": 3,
#     "rows": 4013,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0.02,
#     "columns": 8239,
#     "updated": "2018-06-30T07:50:44Z",
#     "quality_category": "standard",
#     "sun_azimuth": 66.4,
#     "origin_y": 1677762,
#     "origin_x": 561933,
#     "view_angle": 0.1,
#     "strip_id": "1532344",
#     "cloud_cover": 0.19,
#     "gsd": 3.6,
#     "published": "2018-06-30T02:38:24Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.56452255225112,
#        15.195105071413726
#       ],
#       [
#        105.56441609541129,
#        15.195658986768835
#       ],
#       [
#        105.78110464628024,
#        15.235557265808596
#       ],
#       [
#        105.78742491067389,
#        15.203595722151436
#       ],
#       [
#        105.79438666695604,
#        15.167242800151428
#       ],
#       [
#        105.57765393945543,
#        15.127357903923434
#       ],
#       [
#        105.57407207507511,
#        15.145417072645975
#       ],
#       [
#        105.56656408615657,
#        15.184482578955347
#       ],
#       [
#        105.56662245028271,
#        15.184493314183513
#       ],
#       [
#        105.56452255225112,
#        15.195105071413726
#       ]
#      ]
#     ]
#    },
#    "id": "20180629_032537_1053",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180629_032537_1053",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180629_032537_1053/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180629_032537_1053/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-06-29T03:25:37.115946Z",
#     "satellite_id": "1053",
#     "sun_elevation": 66.2,
#     "pixel_resolution": 3,
#     "rows": 4013,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 8239,
#     "updated": "2018-06-30T05:37:10Z",
#     "quality_category": "standard",
#     "sun_azimuth": 66.5,
#     "origin_y": 1684533,
#     "origin_x": 560622,
#     "view_angle": 0.1,
#     "strip_id": "1532344",
#     "cloud_cover": 0.11,
#     "gsd": 3.6,
#     "published": "2018-06-29T16:16:11Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.79504748418692,
#        15.1055359917643
#       ],
#       [
#        105.55924117910247,
#        15.151278329767003
#       ],
#       [
#        105.57460245268739,
#        15.225081565087812
#       ],
#       [
#        105.81035987943271,
#        15.179361582435599
#       ],
#       [
#        105.80814672007588,
#        15.168773568704777
#       ],
#       [
#        105.80828524467043,
#        15.16874670300974
#       ],
#       [
#        105.79504748418692,
#        15.1055359917643
#       ]
#      ]
#     ]
#    },
#    "id": "20180629_025659_0f3f",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180629_025659_0f3f",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180629_025659_0f3f/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180629_025659_0f3f/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-06-29T02:56:59.439683Z",
#     "satellite_id": "0f3f",
#     "sun_elevation": 59.8,
#     "pixel_resolution": 3,
#     "rows": 4384,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0.01,
#     "columns": 8991,
#     "updated": "2018-06-30T04:07:46Z",
#     "quality_category": "standard",
#     "sun_azimuth": 69.6,
#     "origin_y": 1683303,
#     "origin_x": 560079,
#     "view_angle": 0,
#     "strip_id": "1531496",
#     "cloud_cover": 0.12,
#     "gsd": 3.9,
#     "published": "2018-06-29T06:30:09Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.7842609663558,
#        15.208709939640483
#       ],
#       [
#        105.78112317632204,
#        15.22497251011144
#       ],
#       [
#        105.99464595088936,
#        15.264367337333365
#       ],
#       [
#        105.99666648638258,
#        15.25383522098383
#       ],
#       [
#        105.99700540003816,
#        15.253897808355719
#       ],
#       [
#        106.00814051361907,
#        15.197399754870611
#       ],
#       [
#        105.79445555545936,
#        15.157952004542114
#       ],
#       [
#        105.78433906634305,
#        15.20872437639735
#       ],
#       [
#        105.7842609663558,
#        15.208709939640483
#       ]
#      ]
#     ]
#    },
#    "id": "20180628_032507_0f46",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180628_032507_0f46",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180628_032507_0f46/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180628_032507_0f46/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-06-28T03:25:07.596966Z",
#     "satellite_id": "0f46",
#     "sun_elevation": 66.3,
#     "pixel_resolution": 3,
#     "rows": 3954,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 8133,
#     "updated": "2018-06-29T06:02:44Z",
#     "quality_category": "standard",
#     "sun_azimuth": 66.3,
#     "origin_y": 1687812,
#     "origin_x": 583890,
#     "view_angle": 0.2,
#     "strip_id": "1530053",
#     "cloud_cover": 0.18,
#     "gsd": 3.5,
#     "published": "2018-06-28T14:17:14Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.91163435550561,
#        15.033476327363312
#       ],
#       [
#        105.67436104024952,
#        15.079178321554704
#       ],
#       [
#        105.68969061616497,
#        15.153308738565215
#       ],
#       [
#        105.92682380194465,
#        15.107620565431608
#       ],
#       [
#        105.92455378013784,
#        15.096685660222754
#       ],
#       [
#        105.92473699308881,
#        15.096650380095808
#       ],
#       [
#        105.91163435550561,
#        15.033476327363312
#       ]
#      ]
#     ]
#    },
#    "id": "20180627_025613_1044",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180627_025613_1044",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180627_025613_1044/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180627_025613_1044/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-06-27T02:56:13.991349Z",
#     "satellite_id": "1044",
#     "sun_elevation": 59.7,
#     "pixel_resolution": 3,
#     "rows": 4391,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 9041,
#     "updated": "2018-06-28T06:34:16Z",
#     "quality_category": "standard",
#     "sun_azimuth": 69.3,
#     "origin_y": 1675401,
#     "origin_x": 572472,
#     "view_angle": 0.1,
#     "strip_id": "1527601",
#     "cloud_cover": 0.17,
#     "gsd": 3.9,
#     "published": "2018-06-27T16:33:28Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.6947424163842,
#        15.17992878202946
#       ],
#       [
#        105.70088479342509,
#        15.209556346076216
#       ],
#       [
#        105.70112742567271,
#        15.209509662291907
#       ],
#       [
#        105.70338251958896,
#        15.220729921593952
#       ],
#       [
#        105.94047618941251,
#        15.175062657599298
#       ],
#       [
#        105.93133462941834,
#        15.129429612526993
#       ],
#       [
#        105.92541860635251,
#        15.100886010018236
#       ],
#       [
#        105.6880502145217,
#        15.14658277490558
#       ],
#       [
#        105.6947424163842,
#        15.17992878202946
#       ]
#      ]
#     ]
#    },
#    "id": "20180627_025612_1044",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180627_025612_1044",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180627_025612_1044/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180627_025612_1044/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-06-27T02:56:12.929665Z",
#     "satellite_id": "1044",
#     "sun_elevation": 59.8,
#     "pixel_resolution": 3,
#     "rows": 4390,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 9037,
#     "updated": "2018-06-28T06:35:57Z",
#     "quality_category": "standard",
#     "sun_azimuth": 69.5,
#     "origin_y": 1682862,
#     "origin_x": 573921,
#     "view_angle": 0.1,
#     "strip_id": "1527601",
#     "cloud_cover": 0.1,
#     "gsd": 3.9,
#     "published": "2018-06-27T14:18:47Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.69077536365214,
#        15.12824643236588
#       ],
#       [
#        105.92440249649508,
#        15.083418947729465
#       ],
#       [
#        105.9097224699924,
#        15.010231621237587
#       ],
#       [
#        105.67584211269917,
#        15.055076970341771
#       ],
#       [
#        105.68807997626759,
#        15.116466467847841
#       ],
#       [
#        105.68841455653923,
#        15.11640233921051
#       ],
#       [
#        105.69077536365214,
#        15.12824643236588
#       ]
#      ]
#     ]
#    },
#    "id": "20180601_025515_1012",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180601_025515_1012",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180601_025515_1012/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180601_025515_1012/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-06-01T02:55:15.991992Z",
#     "satellite_id": "1012",
#     "sun_elevation": 60.9,
#     "pixel_resolution": 3,
#     "rows": 4324,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 8902,
#     "updated": "2018-06-02T04:16:27Z",
#     "quality_category": "standard",
#     "sun_azimuth": 71.5,
#     "origin_y": 1672629,
#     "origin_x": 572640,
#     "view_angle": 0.2,
#     "strip_id": "1470368",
#     "cloud_cover": 0.01,
#     "gsd": 3.9,
#     "published": "2018-06-01T06:33:04Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.69968031944063,
#        15.172922308394277
#       ],
#       [
#        105.70158731384741,
#        15.182191082641062
#       ],
#       [
#        105.70213564636403,
#        15.182086084402762
#       ],
#       [
#        105.70444416333397,
#        15.193659524816553
#       ],
#       [
#        105.93799550598428,
#        15.148842923686887
#       ],
#       [
#        105.9252881896011,
#        15.085461638834548
#       ],
#       [
#        105.92327097335092,
#        15.075689326765415
#       ],
#       [
#        105.68924075074104,
#        15.12054732887831
#       ],
#       [
#        105.69968031944063,
#        15.172922308394277
#       ]
#      ]
#     ]
#    },
#    "id": "20180601_025514_1012",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180601_025514_1012",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180601_025514_1012/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180601_025514_1012/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-06-01T02:55:14.949183Z",
#     "satellite_id": "1012",
#     "sun_elevation": 61,
#     "pixel_resolution": 3,
#     "rows": 4321,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 8907,
#     "updated": "2018-06-02T04:16:51Z",
#     "quality_category": "standard",
#     "sun_azimuth": 71.6,
#     "origin_y": 1679868,
#     "origin_x": 574056,
#     "view_angle": 0.3,
#     "strip_id": "1470368",
#     "cloud_cover": 0,
#     "gsd": 3.9,
#     "published": "2018-06-01T06:33:04Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.71830046672083,
#        15.25931133660807
#       ],
#       [
#        105.95151130891058,
#        15.21460773415741
#       ],
#       [
#        105.93683443361301,
#        15.14144513241419
#       ],
#       [
#        105.70296239113144,
#        15.186230858483885
#       ],
#       [
#        105.71534638442819,
#        15.248316349026279
#       ],
#       [
#        105.71607868217558,
#        15.248176136242213
#       ],
#       [
#        105.71830046672083,
#        15.25931133660807
#       ]
#      ]
#     ]
#    },
#    "id": "20180601_025513_1012",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180601_025513_1012",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180601_025513_1012/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180601_025513_1012/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-06-01T02:55:13.906374Z",
#     "satellite_id": "1012",
#     "sun_elevation": 61,
#     "pixel_resolution": 3,
#     "rows": 4318,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 8896,
#     "updated": "2018-06-02T04:16:33Z",
#     "quality_category": "standard",
#     "sun_azimuth": 71.7,
#     "origin_y": 1687137,
#     "origin_x": 575508,
#     "view_angle": 0.2,
#     "strip_id": "1470368",
#     "cloud_cover": 0,
#     "gsd": 3.9,
#     "published": "2018-06-01T06:33:04Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.71085008235853,
#        15.12374553204685
#       ],
#       [
#        105.49100617142649,
#        15.082473152450303
#       ],
#       [
#        105.47741238125275,
#        15.151785872375669
#       ],
#       [
#        105.69702313356139,
#        15.193075883475101
#       ],
#       [
#        105.69936865886005,
#        15.181066409708174
#       ],
#       [
#        105.69964270413766,
#        15.181117835173069
#       ],
#       [
#        105.71085008235853,
#        15.12374553204685
#       ]
#      ]
#     ]
#    },
#    "id": "20180601_033001_0f2d",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180601_033001_0f2d",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180601_033001_0f2d/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180601_033001_0f2d/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-06-01T03:30:01.75371Z",
#     "satellite_id": "0f2d",
#     "sun_elevation": 68.6,
#     "pixel_resolution": 3,
#     "rows": 4099,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 8364,
#     "updated": "2018-06-02T05:04:06Z",
#     "quality_category": "standard",
#     "sun_azimuth": 67.8,
#     "origin_y": 1679802,
#     "origin_x": 551289,
#     "view_angle": 0.2,
#     "strip_id": "1470360",
#     "cloud_cover": 0.02,
#     "gsd": 3.6,
#     "published": "2018-06-01T06:29:35Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.49998059443426,
#        15.038068976641432
#       ],
#       [
#        105.48970631788438,
#        15.090391873431408
#       ],
#       [
#        105.70930268762845,
#        15.131666885084192
#       ],
#       [
#        105.71164876426131,
#        15.1196569558139
#       ],
#       [
#        105.71191767994756,
#        15.119707438421472
#       ],
#       [
#        105.71587245343771,
#        15.100079625507114
#       ],
#       [
#        105.72323916906068,
#        15.062361079331946
#       ],
#       [
#        105.50341735193079,
#        15.021085798435914
#       ],
#       [
#        105.49998059443426,
#        15.038068976641432
#       ]
#      ]
#     ]
#    },
#    "id": "20180601_033000_0f2d",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180601_033000_0f2d",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180601_033000_0f2d/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180601_033000_0f2d/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-06-01T03:30:00.791117Z",
#     "satellite_id": "0f2d",
#     "sun_elevation": 68.6,
#     "pixel_resolution": 3,
#     "rows": 4098,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 8370,
#     "updated": "2018-06-02T05:04:34Z",
#     "quality_category": "standard",
#     "sun_azimuth": 67.7,
#     "origin_y": 1673013,
#     "origin_x": 552624,
#     "view_angle": 0.2,
#     "strip_id": "1470360",
#     "cloud_cover": 0.08,
#     "gsd": 3.6,
#     "published": "2018-06-01T06:29:35Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.63483168394943,
#        15.045998221922295
#       ],
#       [
#        105.62845411150815,
#        15.078875073575494
#       ],
#       [
#        105.6285750918577,
#        15.078897469293864
#       ],
#       [
#        105.62627802691419,
#        15.0903817320355
#       ],
#       [
#        105.84530177930833,
#        15.130860036185691
#       ],
#       [
#        105.85477755387136,
#        15.083066716178779
#       ],
#       [
#        105.85886614950049,
#        15.061807567941091
#       ],
#       [
#        105.63975160589605,
#        15.021318285674345
#       ],
#       [
#        105.63483168394943,
#        15.045998221922295
#       ]
#      ]
#     ]
#    },
#    "id": "20180527_032956_1043",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180527_032956_1043",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180527_032956_1043/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180527_032956_1043/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-05-27T03:29:56.880495Z",
#     "satellite_id": "1043",
#     "sun_elevation": 69.1,
#     "pixel_resolution": 3,
#     "rows": 4065,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 8337,
#     "updated": "2018-05-28T08:28:10Z",
#     "quality_category": "standard",
#     "sun_azimuth": 69.5,
#     "origin_y": 1672977,
#     "origin_x": 567300,
#     "view_angle": 0,
#     "strip_id": "1457376",
#     "cloud_cover": 0.12,
#     "gsd": 3.6,
#     "published": "2018-05-27T06:35:40Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        106.00026560924468,
#        15.03902902460367
#       ],
#       [
#        105.76602716631393,
#        15.084302618816206
#       ],
#       [
#        105.77842919048723,
#        15.146126223337186
#       ],
#       [
#        105.77888454198268,
#        15.146038353747874
#       ],
#       [
#        105.7811920284921,
#        15.15754192826783
#       ],
#       [
#        106.01504572174676,
#        15.112318680819616
#       ],
#       [
#        106.00073096746759,
#        15.041272257044193
#       ],
#       [
#        106.00026560924468,
#        15.03902902460367
#       ]
#      ]
#     ]
#    },
#    "id": "20180523_025437_1039",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180523_025437_1039",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180523_025437_1039/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180523_025437_1039/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-05-23T02:54:37.302655Z",
#     "satellite_id": "1039",
#     "sun_elevation": 61.3,
#     "pixel_resolution": 3,
#     "rows": 4339,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 8918,
#     "updated": "2018-05-24T08:00:17Z",
#     "quality_category": "standard",
#     "sun_azimuth": 74.6,
#     "origin_y": 1675902,
#     "origin_x": 582321,
#     "view_angle": 0.2,
#     "strip_id": "1447543",
#     "cloud_cover": 0,
#     "gsd": 3.9,
#     "published": "2018-05-23T17:47:47Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.79470179526452,
#        15.223461241475636
#       ],
#       [
#        106.0287503343662,
#        15.178239962316102
#       ],
#       [
#        106.01393421394205,
#        15.10499074823506
#       ],
#       [
#        105.77971723992022,
#        15.150189625158598
#       ],
#       [
#        105.7921122295754,
#        15.211982700259917
#       ],
#       [
#        105.79238852266275,
#        15.211929415639231
#       ],
#       [
#        105.79470179526452,
#        15.223461241475636
#       ]
#      ]
#     ]
#    },
#    "id": "20180523_025436_1039",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180523_025436_1039",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180523_025436_1039/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180523_025436_1039/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-05-23T02:54:36.259322Z",
#     "satellite_id": "1039",
#     "sun_elevation": 61.3,
#     "pixel_resolution": 3,
#     "rows": 4337,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 8915,
#     "updated": "2018-05-24T08:04:04Z",
#     "quality_category": "standard",
#     "sun_azimuth": 74.7,
#     "origin_y": 1683198,
#     "origin_x": 583767,
#     "view_angle": 0.2,
#     "strip_id": "1447543",
#     "cloud_cover": 0.01,
#     "gsd": 3.9,
#     "published": "2018-05-23T17:47:47Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.61036606866003,
#        15.187903543269961
#       ],
#       [
#        105.60580373060458,
#        15.21114742384294
#       ],
#       [
#        105.60642241580167,
#        15.21126351298237
#       ],
#       [
#        105.60405462660009,
#        15.223023676891279
#       ],
#       [
#        105.82339049241052,
#        15.264181623416144
#       ],
#       [
#        105.83241389291409,
#        15.219304514462051
#       ],
#       [
#        105.837114499748,
#        15.195202310066541
#       ],
#       [
#        105.6172401937761,
#        15.153958411500033
#       ],
#       [
#        105.61036606866003,
#        15.187903543269961
#       ]
#      ]
#     ]
#    },
#    "id": "20180520_033118_1020",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180520_033118_1020",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180520_033118_1020/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180520_033118_1020/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-05-20T03:31:18.139697Z",
#     "satellite_id": "1020",
#     "sun_elevation": 69.8,
#     "pixel_resolution": 3,
#     "rows": 4090,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 8348,
#     "updated": "2018-05-21T10:11:48Z",
#     "quality_category": "standard",
#     "sun_azimuth": 73.3,
#     "origin_y": 1687716,
#     "origin_x": 564873,
#     "view_angle": 0.1,
#     "strip_id": "1439537",
#     "cloud_cover": 0.02,
#     "gsd": 3.6,
#     "published": "2018-05-20T07:01:44Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.6158118878534,
#        15.161011531996822
#       ],
#       [
#        105.83543378228126,
#        15.202240641950338
#       ],
#       [
#        105.8493302287335,
#        15.133294128017585
#       ],
#       [
#        105.62954162154527,
#        15.09205086647999
#       ],
#       [
#        105.6179124862406,
#        15.149512675375787
#       ],
#       [
#        105.61813214226092,
#        15.149553878801221
#       ],
#       [
#        105.6158118878534,
#        15.161011531996822
#       ]
#      ]
#     ]
#    },
#    "id": "20180520_033117_1020",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180520_033117_1020",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180520_033117_1020/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180520_033117_1020/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-05-20T03:31:17.169764Z",
#     "satellite_id": "1020",
#     "sun_elevation": 69.8,
#     "pixel_resolution": 3,
#     "rows": 4088,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 8368,
#     "updated": "2018-05-21T10:15:18Z",
#     "quality_category": "standard",
#     "sun_azimuth": 73.1,
#     "origin_y": 1680867,
#     "origin_x": 566154,
#     "view_angle": 0.1,
#     "strip_id": "1439537",
#     "cloud_cover": 0.04,
#     "gsd": 3.6,
#     "published": "2018-05-20T07:01:44Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.63739551237384,
#        15.051222838087963
#       ],
#       [
#        105.6302597837555,
#        15.08761420491623
#       ],
#       [
#        105.63043293879596,
#        15.08764669538878
#       ],
#       [
#        105.62811156192224,
#        15.099117067931362
#       ],
#       [
#        105.84774673724722,
#        15.140309303002043
#       ],
#       [
#        105.85459395921221,
#        15.106355507103599
#       ],
#       [
#        105.86141950886882,
#        15.07133264292917
#       ],
#       [
#        105.6416650478542,
#        15.03012300926912
#       ],
#       [
#        105.63739551237384,
#        15.051222838087963
#       ]
#      ]
#     ]
#    },
#    "id": "20180520_033116_1020",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180520_033116_1020",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180520_033116_1020/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180520_033116_1020/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-05-20T03:31:16.199831Z",
#     "satellite_id": "1020",
#     "sun_elevation": 69.8,
#     "pixel_resolution": 3,
#     "rows": 4088,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 8363,
#     "updated": "2018-05-21T10:14:06Z",
#     "quality_category": "standard",
#     "sun_azimuth": 73,
#     "origin_y": 1674021,
#     "origin_x": 567495,
#     "view_angle": 0.1,
#     "strip_id": "1439537",
#     "cloud_cover": 0.01,
#     "gsd": 3.6,
#     "published": "2018-05-20T07:01:44Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.68341731007197,
#        15.109843245623232
#       ],
#       [
#        105.91628807129935,
#        15.064931511428389
#       ],
#       [
#        105.90139396111157,
#        14.991349441416968
#       ],
#       [
#        105.66867481255134,
#        15.036192241818814
#       ],
#       [
#        105.67950650201705,
#        15.09030524161777
#       ],
#       [
#        105.6795030238259,
#        15.090305909084805
#       ],
#       [
#        105.68341731007197,
#        15.109843245623232
#       ]
#      ]
#     ]
#    },
#    "id": "20180519_025453_0f4e",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180519_025453_0f4e",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180519_025453_0f4e/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180519_025453_0f4e/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-05-19T02:54:53.291133Z",
#     "satellite_id": "0f4e",
#     "sun_elevation": 61.6,
#     "pixel_resolution": 3,
#     "rows": 4342,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0.01,
#     "columns": 8869,
#     "updated": "2018-05-20T07:57:45Z",
#     "quality_category": "standard",
#     "sun_azimuth": 76.4,
#     "origin_y": 1670592,
#     "origin_x": 571875,
#     "view_angle": 2.3,
#     "strip_id": "1437090",
#     "cloud_cover": 0.01,
#     "gsd": 3.9,
#     "published": "2018-05-19T12:30:19Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.91562253315024,
#        15.057205488906515
#       ],
#       [
#        105.68189586587695,
#        15.102152602559668
#       ],
#       [
#        105.69435892291641,
#        15.162371192776595
#       ],
#       [
#        105.69609812911548,
#        15.162037151401945
#       ],
#       [
#        105.69877312981995,
#        15.175379349391179
#       ],
#       [
#        105.93088964290732,
#        15.130721248744804
#       ],
#       [
#        105.92686219305666,
#        15.110826222244247
#       ],
#       [
#        105.92674092060416,
#        15.110849418752386
#       ],
#       [
# ...
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-02-12T03:45:11.196335Z",
#     "satellite_id": "1020",
#     "sun_elevation": 54.1,
#     "pixel_resolution": 3,
#     "rows": 4106,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 8408,
#     "updated": "2018-02-13T07:46:34Z",
#     "quality_category": "standard",
#     "sun_azimuth": 142.6,
#     "origin_y": 1685415,
#     "origin_x": 568962,
#     "view_angle": 0.2,
#     "strip_id": "1166537",
#     "cloud_cover": 0.06,
#     "gsd": 3.7,
#     "published": "2018-02-12T10:27:54Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.65414578878965,
#        15.140227986811086
#       ],
#       [
#        105.87449006210433,
#        15.181496905094154
#       ],
#       [
#        105.88841651739372,
#        15.112270945530524
#       ],
#       [
#        105.66746309983355,
#        15.070902020040505
#       ],
#       [
#        105.65596939343561,
#        15.127859633378515
#       ],
#       [
#        105.65661456311166,
#        15.127980400026333
#       ],
#       [
#        105.65414578878965,
#        15.140227986811086
#       ]
#      ]
#     ]
#    },
#    "id": "20180212_034510_1020",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180212_034510_1020",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180212_034510_1020/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180212_034510_1020/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-02-12T03:45:10.230359Z",
#     "satellite_id": "1020",
#     "sun_elevation": 54.2,
#     "pixel_resolution": 3,
#     "rows": 4105,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 8396,
#     "updated": "2018-02-13T07:46:18Z",
#     "quality_category": "standard",
#     "sun_azimuth": 142.6,
#     "origin_y": 1678590,
#     "origin_x": 570279,
#     "view_angle": 0.1,
#     "strip_id": "1166537",
#     "cloud_cover": 0.04,
#     "gsd": 3.7,
#     "published": "2018-02-12T10:27:54Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.66592871655845,
#        15.07850572995527
#       ],
#       [
#        105.88642498113394,
#        15.119821686607116
#       ],
#       [
#        105.90033943670404,
#        15.050595475638842
#       ],
#       [
#        105.67915201783755,
#        15.009159643668994
#       ],
#       [
#        105.66765974965548,
#        15.066131923712831
#       ],
#       [
#        105.6683977928468,
#        15.066270103981847
#       ],
#       [
#        105.66592871655845,
#        15.07850572995527
#       ]
#      ]
#     ]
#    },
#    "id": "20180212_034509_1020",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180212_034509_1020",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180212_034509_1020/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180212_034509_1020/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-02-12T03:45:09.264383Z",
#     "satellite_id": "1020",
#     "sun_elevation": 54.3,
#     "pixel_resolution": 3,
#     "rows": 4108,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 8403,
#     "updated": "2018-02-13T07:45:38Z",
#     "quality_category": "standard",
#     "sun_azimuth": 142.5,
#     "origin_y": 1671774,
#     "origin_x": 571566,
#     "view_angle": 0.2,
#     "strip_id": "1166537",
#     "cloud_cover": 0.01,
#     "gsd": 3.7,
#     "published": "2018-02-12T10:27:53Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.95656850228652,
#        15.03023512493444
#       ],
#       [
#        105.7236957838522,
#        15.075710169193405
#       ],
#       [
#        105.73888175107602,
#        15.14837127821993
#       ],
#       [
#        105.9713985088153,
#        15.102842106226793
#       ],
#       [
#        105.96927167164537,
#        15.092696999716344
#       ],
#       [
#        105.96967516801274,
#        15.092618233170628
#       ],
#       [
#        105.95656850228652,
#        15.03023512493444
#       ]
#      ]
#     ]
#    },
#    "id": "20180212_025100_1018",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180212_025100_1018",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180212_025100_1018/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180212_025100_1018/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-02-12T02:51:00.094969Z",
#     "satellite_id": "1018",
#     "sun_elevation": 45.1,
#     "pixel_resolution": 3,
#     "rows": 4327,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 8871,
#     "updated": "2018-02-13T05:56:39Z",
#     "quality_category": "standard",
#     "sun_azimuth": 128.2,
#     "origin_y": 1674873,
#     "origin_x": 577776,
#     "view_angle": 1.3,
#     "strip_id": "1166141",
#     "cloud_cover": 0,
#     "gsd": 3.9,
#     "published": "2018-02-12T06:15:57Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.97017791148659,
#        15.097019803475433
#       ],
#       [
#        105.73714277423086,
#        15.142517691758822
#       ],
#       [
#        105.75234758260416,
#        15.215159426367856
#       ],
#       [
#        105.98530774215133,
#        15.16949952494412
#       ],
#       [
#        105.98322123761288,
#        15.15955719236996
#       ],
#       [
#        105.98328571782473,
#        15.159544614165705
#       ],
#       [
#        105.97017791148659,
#        15.097019803475433
#       ]
#      ]
#     ]
#    },
#    "id": "20180212_025059_1018",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180212_025059_1018",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180212_025059_1018/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180212_025059_1018/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-02-12T02:50:59.044709Z",
#     "satellite_id": "1018",
#     "sun_elevation": 45,
#     "pixel_resolution": 3,
#     "rows": 4327,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 8885,
#     "updated": "2018-02-13T05:57:40Z",
#     "quality_category": "standard",
#     "sun_azimuth": 128.3,
#     "origin_y": 1682265,
#     "origin_x": 579195,
#     "view_angle": 1.3,
#     "strip_id": "1166141",
#     "cloud_cover": 0,
#     "gsd": 3.9,
#     "published": "2018-02-12T06:15:57Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.74399408886926,
#        15.097959574638674
#       ],
#       [
#        105.50815867390246,
#        15.144122639922633
#       ],
#       [
#        105.52369926154667,
#        15.21795931142572
#       ],
#       [
#        105.7591459694074,
#        15.172133554141666
#       ],
#       [
#        105.75654427880265,
#        15.159844960213608
#       ],
#       [
#        105.75706113811886,
#        15.159743721179236
#       ],
#       [
#        105.74399408886926,
#        15.097959574638674
#       ]
#      ]
#     ]
#    },
#    "id": "20180211_025243_1014",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180211_025243_1014",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180211_025243_1014/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180211_025243_1014/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-02-11T02:52:43.532242Z",
#     "satellite_id": "1014",
#     "sun_elevation": 44.7,
#     "pixel_resolution": 3,
#     "rows": 4402,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 8987,
#     "updated": "2018-02-12T05:50:03Z",
#     "quality_category": "standard",
#     "sun_azimuth": 128.5,
#     "origin_y": 1682502,
#     "origin_x": 554592,
#     "view_angle": 3.3,
#     "strip_id": "1163689",
#     "cloud_cover": 0,
#     "gsd": 3.9,
#     "published": "2018-02-11T16:19:57Z"
#    }
#   },
#   {
#    "geometry": {
#     "type": "Polygon",
#     "coordinates": [
#      [
#       [
#        105.49543316427425,
#        15.081888325506718
#       ],
#       [
#        105.51018032137644,
#        15.1517622609042
#       ],
#       [
#        105.7456828271194,
#        15.10594433458882
#       ],
#       [
#        105.74306731274822,
#        15.093577554598898
#       ],
#       [
#        105.74367169399794,
#        15.093459211744921
#       ],
#       [
#        105.74366649122449,
#        15.09343387334142
#       ],
#       [
#        105.73061535466721,
#        15.031763117162336
#       ],
#       [
#        105.494629279992,
#        15.077953169394991
#       ],
#       [
#        105.49543316427425,
#        15.081888325506718
#       ]
#      ]
#     ]
#    },
#    "id": "20180211_025244_1014",
#    "_links": {
#     "_self": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180211_025244_1014",
#     "assets": "https://api.planet.com/data/v1/item-types/PSScene4Band/items/20180211_025244_1014/assets/",
#     "thumbnail": "https://tiles.planet.com/data/v1/item-types/PSScene4Band/items/20180211_025244_1014/thumb"
#    },
#    "_permissions": [
#     "assets.basic_analytic_rpc_nitf:download",
#     "assets.analytic_xml:download",
#     "assets.basic_analytic_dn:download",
#     "assets.basic_analytic_dn_xml_nitf:download",
#     "assets.basic_analytic_dn_nitf:download",
#     "assets.basic_analytic_xml:download",
#     "assets.basic_analytic_nitf:download",
#     "assets.basic_analytic_rpc:download",
#     "assets.analytic_dn:download",
#     "assets.basic_udm:download",
#     "assets.basic_analytic_dn_rpc_nitf:download",
#     "assets.analytic:download",
#     "assets.analytic_dn_xml:download",
#     "assets.analytic_sr:download",
#     "assets.basic_analytic_dn_xml:download",
#     "assets.basic_analytic_dn_rpc:download",
#     "assets.basic_analytic_xml_nitf:download",
#     "assets.basic_analytic:download",
#     "assets.udm:download"
#    ],
#    "type": "Feature",
#    "properties": {
#     "acquired": "2018-02-11T02:52:44.574992Z",
#     "satellite_id": "1014",
#     "sun_elevation": 44.7,
#     "pixel_resolution": 3,
#     "rows": 4403,
#     "epsg_code": 32648,
#     "item_type": "PSScene4Band",
#     "usable_data": 0,
#     "instrument": "PS2",
#     "ground_control": true,
#     "provider": "planetscope",
#     "anomalous_pixels": 0,
#     "columns": 8992,
#     "updated": "2018-02-12T05:48:59Z",
#     "quality_category": "standard",
#     "sun_azimuth": 128.5,
#     "origin_y": 1675176,
#     "origin_x": 553155,
#     "view_angle": 3.3,
#     "strip_id": "1163689",
#     "cloud_cover": 0,
#     "gsd": 3.9,
#     "published": "2018-02-11T14:28:49Z"
#    }
#   }
#  ]
# }

# %%
# extract image IDs
image_ids = [feature['id'] for feature in search_result.json()['features']]
print(image_ids)
# Out:
# [u'20180629_032536_1053', u'20180629_032537_1053', u'20180629_025659_0f3f', u'20180628_032507_0f46', u'20180627_025613_1044', u'20180627_025612_1044', u'20180601_025515_1012', u'20180601_025514_1012', u'20180601_025513_1012', u'20180601_033001_0f2d', u'20180601_033000_0f2d', u'20180527_032956_1043', u'20180523_025437_1039', u'20180523_025436_1039', u'20180520_033118_1020', u'20180520_033117_1020', u'20180520_033116_1020', u'20180519_025453_0f4e', u'20180519_025452_0f4e', u'20180519_025451_0f4e', u'20180517_025516_1014', u'20180512_033225_0f2a', u'20180513_033141_0f21', u'20180513_033142_0f21', u'20180512_033224_0f2a', u'20180512_033223_0f2a', u'20180512_025551_0f28', u'20180512_025549_0f28', u'20180512_025550_0f28', u'20180512_025434_0f17', u'20180512_025436_0f17', u'20180512_025435_0f17', u'20180511_033301_0f40', u'20180509_025428_1009', u'20180509_025427_1009', u'20180509_025426_1009', u'20180509_001623_0c38', u'20180509_001622_0c38', u'20180508_025506_1033', u'20180508_025505_1033', u'20180501_033418_0f2d', u'20180501_033417_0f2d', u'20180501_025419_102c', u'20180501_025418_102c', u'20180428_025433_1038', u'20180428_025432_1038', u'20180427_025456_1005', u'20180427_025454_1005', u'20180424_025446_1006', u'20180424_025445_1006', u'20180424_025444_1006', u'20180424_033440_0f33', u'20180424_033439_0f33', u'20180423_025434_1036', u'20180423_025433_1036', u'20180423_025431_1036', u'20180423_033426_100d', u'20180423_033425_100d', u'20180422_025352_1021', u'20180422_025351_1021', u'20180422_033453_104b', u'20180422_033454_104b', u'20180420_033522_0f4b', u'20180419_025341_0f4e', u'20180419_025340_0f4e', u'20180419_033548_1049', u'20180419_033549_1049', u'20180419_033547_1049', u'20180418_025358_100e', u'20180418_025357_100e', u'20180418_033626_0f3c', u'20180418_033625_0f3c', u'20180418_033624_0f3c', u'20180417_025422_1035', u'20180416_025358_101b', u'20180416_025357_101b', u'20180416_025356_101b', u'20180416_033638_104e', u'20180416_033637_104e', u'20180416_033636_104e', u'20180412_061137_0f02', u'20180412_061136_0f02', u'20180411_025333_102e', u'20180411_025332_102e', u'20180410_025303_103e', u'20180410_025302_103e', u'20180410_025415_1039', u'20180410_025414_1039', u'20180409_025349_100c', u'20180409_025348_100c', u'20180409_025347_100c', u'20180409_025237_0f18', u'20180409_025236_0f18', u'20180408_061238_0f4c', u'20180408_061236_0f4c', u'20180408_025234_0e26', u'20180408_025233_0e26', u'20180404_025401_0e2f', u'20180404_025218_0f12', u'20180404_025217_0f12', u'20180404_025400_0e2f', u'20180404_025359_0e2f', u'20180403_033824_103f', u'20180403_033823_103f', u'20180403_025356_103c', u'20180403_025355_103c', u'20180402_025335_1011', u'20180401_025235_1002', u'20180401_025234_1002', u'20180401_025233_1002', u'20180402_025334_1011', u'20180331_025239_1032', u'20180331_025237_1032', u'20180328_025208_1024', u'20180328_025207_1024', u'20180320_025246_101e', u'20180320_033948_0f21', u'20180320_033947_0f21', u'20180328_033857_0f29', u'20180328_033856_0f29', u'20180327_025325_0f18', u'20180327_033917_104d', u'20180327_025324_0f18', u'20180327_033918_104d', u'20180327_033916_104d', u'20180327_025209_1009', u'20180327_025211_1009', u'20180319_025254_1002', u'20180319_025253_1002', u'20180326_025310_1033', u'20180326_025311_1033', u'20180325_025509_0e3a', u'20180325_025508_0e3a', u'20180325_033851_1053', u'20180325_033852_1053', u'20180325_025219_1004', u'20180318_034028_0f40', u'20180318_034027_0f40', u'20180318_034026_0f40', u'20180318_025309_1032', u'20180318_025308_1032', u'20180318_025307_1032', u'20180325_025221_1004', u'20180325_033853_1053', u'20180318_025226_1008', u'20180318_025225_1008', u'20180324_033924_0f46', u'20180324_025333_101d', u'20180324_025331_101d', u'20180324_033923_0f46', u'20180323_025235_1003', u'20180323_025226_1018', u'20180322_033916_1050', u'20180322_033915_1050', u'20180316_034105_104a', u'20180316_034104_104a', u'20180316_034103_104a', u'20180315_034135_0f33', u'20180313_025235_0f31', u'20180313_025234_0f31', ...

# %%
# choose the image id that you want to download, here we are using the first one
id0 = image_ids[0]
#use this if you would like to use the asset id you wish to download
#id0 = u'20180629_032537_1053' 
id0_url = 'https://api.planet.com/data/v1/item-types/{}/items/{}/assets'.format(item_type, id0)

# Returns JSON metadata for assets in this ID. Learn more: planet.com/docs/reference/data-api/items-assets/#asset
result = \
  requests.get(
    id0_url,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )

# List of asset types available for this particular satellite image
print(result.json().keys())
# Out:
# [u'basic_analytic_rpc_nitf', u'analytic_xml', u'basic_analytic_dn', u'basic_analytic_dn_xml_nitf', u'basic_analytic_dn_nitf', u'basic_analytic_xml', u'basic_analytic_nitf', u'basic_analytic_rpc', u'analytic_dn', u'basic_udm', u'basic_analytic_dn_rpc_nitf', u'analytic', u'analytic_dn_xml', u'analytic_sr', u'basic_analytic_dn_xml', u'basic_analytic_dn_rpc', u'basic_analytic_xml_nitf', u'basic_analytic', u'udm']

# %%
# This is "inactive" if the "analytic" asset has not yet been activated; otherwise 'active'
print(result.json()['analytic']['status'])
# Out:
# active

# %%
# Parse out useful links
links = result.json()[u"analytic"]["_links"]
self_link = links["_self"]
activation_link = links["activate"]

# if asset is inactive, request activation. without this you cannot get the download link of the scene.
activate_result = \
  requests.get(
    activation_link,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )

# %%
activation_status_result = \
  requests.get(
    self_link,
    auth=HTTPBasicAuth(PLANET_API_KEY, '')
  )

print(activation_status_result.json()["status"])
# Out:
# active

# %%
# once the activation status turns to active, get the download link using
download_link = activation_status_result.json()["location"]
#click on the download link to download the image
print(download_link)
# Out:
# https://api.planet.com/data/v1/download?token=eyJhbGciOiJIUzUxMiIsInR5cCI6IkpXVCJ9..VMaA4ePAbLxTMHeT2-ScEfRFPWy4FyO00lj0LLuJqlXUm59vtLm9RDGakpOMrCJxf1CcZROU-FWfb0O-e_tJDw

# %%
#2 downloading subarea/training sites from planet
from osgeo import gdal

vsicurl_url = '/vsicurl/' + download_link
output_file = id0 + 'subarea3.tif'

# use gdal warp command to download only the subarea you saved as a geojsonfile
gdal.Warp(output_file, vsicurl_url, dstSRS = 'EPSG:4326', cutlineDSName = 'subarea.geojson', cropToCutline = True)

# %%
#3 visualizing NDVI of the scene

# this can be done for the entire scene - depends on your computer processing power

import rasterio
import numpy as np

filename = id0 + 'subarea.tif'

# Load red and NIR bands 
with rasterio.open(filename) as src:
    red = src.read(3)

with rasterio.open(filename) as src:
    nir = src.read(4)

# %%
# This ignores division by zero
np.seterr(divide='ignore', invalid='ignore')

# Calculate NDVI. 
ndvi = (nir.astype(float) - red.astype(float)) / (nir + red)

# %%
# check range NDVI values, excluding Not a number (NaN)
np.nanmin(ndvi), np.nanmax(ndvi)
# Out:
# (-0.5055082103512784, 0.560197493353589)

# %%
#code to get the visualization 
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# Set min/max values from NDVI range for image (excluding NAN)
min=np.nanmin(ndvi)
max=np.nanmax(ndvi)

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

# choose any color scheme you like from https://matplotlib.org/users/colormaps.html 
cmap = plt.cm.RdYlGn 

cax = ax.imshow(ndvi, cmap=cmap, clim=(min, max))

ax.axis('off')
ax.set_title('Normalized Difference Vegetation Index\n', fontsize=14, fontweight='bold')

cbar = fig.colorbar(cax, orientation='vertical')

fig.savefig("ndvi_pakse.png", dpi=200, bbox_inches='tight')

plt.show()
